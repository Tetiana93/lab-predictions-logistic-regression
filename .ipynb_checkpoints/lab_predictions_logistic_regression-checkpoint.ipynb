# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\tetiana\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\tetiana\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tetiana\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\tetiana\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\tetiana\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\tetiana\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tetiana\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)

# %%
import imblearn
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import getpass
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import Normalizer, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)
query = '''
        select distinct film_id, title, rental_duration, rental_rate, length, rating, rental_date, month(rental_date) as month
from film
join inventory using(film_id)
join rental using(inventory_id)
where year(rental_date)=2005;
        '''

data = pd.read_sql_query(query, engine)
data
# Out:
#        film_id             title  rental_duration  rental_rate  length rating  \
# 0            1  ACADEMY DINOSAUR                6         0.99      86     PG
# 1            1  ACADEMY DINOSAUR                6         0.99      86     PG
# 2            1  ACADEMY DINOSAUR                6         0.99      86     PG
# 3            1  ACADEMY DINOSAUR                6         0.99      86     PG
# 4            1  ACADEMY DINOSAUR                6         0.99      86     PG
# ...        ...               ...              ...          ...     ...    ...
# 15457     1000         ZORRO ARK                3         4.99      50  NC-17
# 15458     1000         ZORRO ARK                3         4.99      50  NC-17
# 15459     1000         ZORRO ARK                3         4.99      50  NC-17
# 15460     1000         ZORRO ARK                3         4.99      50  NC-17
# 15461     1000         ZORRO ARK                3         4.99      50  NC-17
#
#               rental_date  month
# 0     2005-07-08 19:03:15      7
# 1     2005-08-02 20:13:10      8
# 2     2005-08-21 21:27:43      8
# 3     2005-05-30 20:21:07      5
# 4     2005-06-17 20:24:00      6
# ...                   ...    ...
# 15457 2005-05-29 03:49:03      5
# 15458 2005-06-15 21:50:32      6
# 15459 2005-07-12 13:24:47      7
# 15460 2005-07-31 07:32:21      7
# 15461 2005-08-19 03:49:28      8
#
# [15462 rows x 8 columns]

# %%
data.shape
# Out:
# (15462, 8)

# %%
data.dtypes
# Out:
# film_id                     int64
# title                      object
# rental_duration             int64
# rental_rate               float64
# length                      int64
# rating                     object
# rental_date        datetime64[ns]
# month                       int64
# dtype: object

# %%
data.describe()
# Out:
#             film_id  rental_duration   rental_rate        length  \
# count  15462.000000     15462.000000  15462.000000  15462.000000
# mean     500.742983         4.938430      2.946021    115.023154
# min        1.000000         3.000000      0.990000     46.000000
# 25%      255.000000         4.000000      0.990000     81.000000
# 50%      496.000000         5.000000      2.990000    114.000000
# 75%      751.000000         6.000000      4.990000    148.000000
# max     1000.000000         7.000000      4.990000    185.000000
# std      288.256793         1.400643      1.649167     40.089346
#
#                          rental_date         month
# count                          15462  15462.000000
# mean   2005-07-21 00:54:21.941598720      7.069202
# min              2005-05-24 22:53:30      5.000000
# 25%       2005-07-06 22:59:29.250000      7.000000
# 50%              2005-07-28 13:34:21      7.000000
# 75%       2005-08-17 16:44:43.750000      8.000000
# max              2005-08-23 22:50:12      8.000000
# std                              NaN      0.889393

# %%
data.isna().sum()
# Out:
# film_id            0
# title              0
# rental_duration    0
# rental_rate        0
# length             0
# rating             0
# rental_date        0
# month              0
# dtype: int64

# %%
for col in data.columns:
    if 'month' in col and (data['month'] == 7).any():
        print(f"Column: {col}")
        print(data[data['month'] == 7]['title'])
        
data['rented_last_month'] = data['month'] == 7
# Out:
# Column: month
# 0        ACADEMY DINOSAUR
# 5        ACADEMY DINOSAUR
# 6        ACADEMY DINOSAUR
# 8        ACADEMY DINOSAUR
# 14       ACADEMY DINOSAUR
#                ...
# 15447           ZORRO ARK
# 15452           ZORRO ARK
# 15453           ZORRO ARK
# 15459           ZORRO ARK
# 15460           ZORRO ARK
# Name: title, Length: 6524, dtype: object

# %%
data.head(50)
# Out:
#     film_id             title  rental_duration  rental_rate  length rating  \
# 0         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 1         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 2         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 3         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 4         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 5         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 6         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 7         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 8         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 9         1  ACADEMY DINOSAUR                6         0.99      86     PG
# 10        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 11        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 12        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 13        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 14        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 15        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 16        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 17        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 18        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 19        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 20        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 21        1  ACADEMY DINOSAUR                6         0.99      86     PG
# 22        2    ACE GOLDFINGER                3         4.99      48      G
# 23        2    ACE GOLDFINGER                3         4.99      48      G
# 24        2    ACE GOLDFINGER                3         4.99      48      G
# 25        2    ACE GOLDFINGER                3         4.99      48      G
# 26        2    ACE GOLDFINGER                3         4.99      48      G
# 27        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 28        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 29        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 30        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 31        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 32        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 33        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 34        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 35        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 36        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 37        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 38        3  ADAPTATION HOLES                7         2.99      50  NC-17
# 39        4  AFFAIR PREJUDICE                5         2.99     117      G
# 40        4  AFFAIR PREJUDICE                5         2.99     117      G
# 41        4  AFFAIR PREJUDICE                5         2.99     117      G
# 42        4  AFFAIR PREJUDICE                5         2.99     117      G
# 43        4  AFFAIR PREJUDICE                5         2.99     117      G
# 44        4  AFFAIR PREJUDICE                5         2.99     117      G
# 45        4  AFFAIR PREJUDICE                5         2.99     117      G
# 46        4  AFFAIR PREJUDICE                5         2.99     117      G
# 47        4  AFFAIR PREJUDICE                5         2.99     117      G
# 48        4  AFFAIR PREJUDICE                5         2.99     117      G
# 49        4  AFFAIR PREJUDICE                5         2.99     117      G
#
#     rental_id         rental_date  month  rented_last_month
# 0        4863 2005-07-08 19:03:15      7               True
# 1       11433 2005-08-02 20:13:10      8              False
# 2       14714 2005-08-21 21:27:43      8              False
# 3         972 2005-05-30 20:21:07      5              False
# 4        2117 2005-06-17 20:24:00      6              False
# 5        4187 2005-07-07 10:41:31      7               True
# 6        9449 2005-07-30 22:02:34      7               True
# 7       15453 2005-08-23 01:01:01      8              False
# 8       10126 2005-07-31 21:36:07      7               True
# 9       15421 2005-08-22 23:56:37      8              False
# 10      10883 2005-08-02 00:47:19      8              False
# 11      14624 2005-08-21 18:32:42      8              False
# 12        361 2005-05-27 07:03:28      5              False
# 13       3201 2005-06-21 00:30:26      6              False
# 14       4390 2005-07-07 20:59:06      7               True
# 15       7168 2005-07-27 07:51:11      7               True
# 16      14098 2005-08-21 00:30:32      8              False
# 17       1210 2005-06-15 02:57:51      6              False
# 18       8510 2005-07-29 09:41:38      7               True
# 19      14798 2005-08-22 00:44:08      8              False
# 20      10141 2005-07-31 22:08:29      7               True
# 21      12651 2005-08-18 18:36:16      8              False
# 22       4364 2005-07-07 19:46:51      7               True
# 23       7733 2005-07-28 05:04:47      7               True
# 24      15218 2005-08-22 16:59:05      8              False
# 25      10992 2005-08-02 04:41:17      8              False
# 26      11758 2005-08-17 09:33:02      8              False
# 27       6999 2005-07-27 01:21:19      7               True
# 28      14882 2005-08-22 03:52:21      8              False
# 29      11306 2005-08-02 15:45:10      8              False
# 30      15788 2005-08-23 13:54:39      8              False
# 31       1033 2005-05-31 04:50:07      5              False
# 32       1427 2005-06-15 18:17:28      6              False
# 33       3897 2005-07-06 19:11:43      7               True
# 34      10437 2005-08-01 08:51:04      8              False
# 35      11845 2005-08-17 13:16:38      8              False
# 36       3956 2005-07-06 22:01:51      7               True
# 37       7586 2005-07-27 23:19:29      7               True
# 38      12727 2005-08-18 21:45:15      8              False
# 39       6493 2005-07-12 02:40:41      7               True
# 40       8931 2005-07-30 02:30:07      7               True
# 41      15352 2005-08-22 21:16:54      8              False
# 42        995 2005-05-31 00:06:02      5              False
# 43       2090 2005-06-17 18:06:14      6              False
# 44       5682 2005-07-10 08:51:39      7               True
# 45       6970 2005-07-27 00:26:14      7               True
# 46      11714 2005-08-17 07:34:55      8              False
# 47       8331 2005-07-29 04:13:29      7               True
# 48      15199 2005-08-22 16:17:49      8              False
# 49       3506 2005-07-06 00:22:29      7               True

# %%
data['rented_last_month'].value_counts()
# Out:
# rented_last_month
# False    8938
# True     6524
# Name: count, dtype: int64

# %%
data = data.set_index('film_id')
data
# Out:
#                     title  rental_duration  rental_rate  length rating  \
# film_id
# 1        ACADEMY DINOSAUR                6         0.99      86     PG
# 1        ACADEMY DINOSAUR                6         0.99      86     PG
# 1        ACADEMY DINOSAUR                6         0.99      86     PG
# 1        ACADEMY DINOSAUR                6         0.99      86     PG
# 1        ACADEMY DINOSAUR                6         0.99      86     PG
# ...                   ...              ...          ...     ...    ...
# 1000            ZORRO ARK                3         4.99      50  NC-17
# 1000            ZORRO ARK                3         4.99      50  NC-17
# 1000            ZORRO ARK                3         4.99      50  NC-17
# 1000            ZORRO ARK                3         4.99      50  NC-17
# 1000            ZORRO ARK                3         4.99      50  NC-17
#
#                 rental_date  month  rented_last_month
# film_id
# 1       2005-07-08 19:03:15      7               True
# 1       2005-08-02 20:13:10      8              False
# 1       2005-08-21 21:27:43      8              False
# 1       2005-05-30 20:21:07      5              False
# 1       2005-06-17 20:24:00      6              False
# ...                     ...    ...                ...
# 1000    2005-05-29 03:49:03      5              False
# 1000    2005-06-15 21:50:32      6              False
# 1000    2005-07-12 13:24:47      7               True
# 1000    2005-07-31 07:32:21      7               True
# 1000    2005-08-19 03:49:28      8              False
#
# [15462 rows x 8 columns]

# %%
data.dtypes
# Out:
# title                        object
# rental_duration               int64
# rental_rate                 float64
# length                        int64
# rating                       object
# rental_date          datetime64[ns]
# month                         int64
# rented_last_month              bool
# dtype: object

# %% [markdown]
# EDA

# %%
# Checking for multi-colinearity (features with correlation around .9, because they carry redundant information that we can remove before training the model)
corr_matrix=data.select_dtypes("number").corr(method='pearson')  # default
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()
